# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("1.8um_Data/pmos_data/pmos_1a_low.txt", 'r') as file:
    lines = [line.rstrip() for line in file][6:]

    voltage = []
    current = []

    for line in lines:
        b, a = line.split("      ")
        voltage.append(float(b))
        current.append(float(a))

    plt.plot(voltage, np.abs(current), label='1.8um Gate Length')

    plt.yscale('log') 

    # Subthreshold Swing Extraction

    #m, b = np.polyfit(voltage[8:15], np.log10(np.abs(current[8:15])), 1)    #nmos
    m, b = np.polyfit(voltage[-15:-8], np.log10(np.abs(current[-15:-8])), 1)    #pmos

    #x_index = np.arange(-0.1, 0.2, 0.01)    #nmos
    x_index = np.arange(-0.2, 0.1, 0.01)    #pmos

    plt.plot(x_index, np.power(10, m*x_index) * np.power(10, b))

    print(1000/m)

with open("1.5um_Data/pmos_data/pmos_1.5_iv_low.txt", 'r') as file:
    lines = [line.rstrip() for line in file][6:]

    voltage = []
    current = []

    for line in lines:
        b, a = line.split("      ")
        voltage.append(float(b))
        current.append(float(a))

    plt.plot(voltage, np.abs(current), label='1.5um Gate Length')

    plt.yscale('log') 

    # Subthreshold Swing Extraction

    #m, b = np.polyfit(voltage[8:14], np.log10(np.abs(current[8:14])), 1)    #nmos
    m, b = np.polyfit(voltage[-15:-8], np.log10(np.abs(current[-15:-8])), 1)    #pmos

    #x_index = np.arange(-0.1, 0.2, 0.01)    #nmos
    x_index = np.arange(-0.2, 0.1, 0.01)    #pmos

    plt.plot(x_index, np.power(10, m*x_index) * np.power(10, b))

    print(1000/m)


with open("1.0um_Data/pmos_data/pmos_1.0_iv_low.txt", 'r') as file:
    lines = [line.rstrip() for line in file][6:]

    voltage = []
    current = []

    for line in lines:
        b, a = line.split("      ")
        voltage.append(float(b))
        current.append(float(a))

    plt.plot(voltage, np.abs(current), label='1.0um Gate Length')

    plt.yscale('log') 

    # Subthreshold Swing Extraction

    #m, b = np.polyfit(voltage[5:11], np.log10(np.abs(current[5:11])), 1)    #nmos
    m, b = np.polyfit(voltage[-13:-7], np.log10(np.abs(current[-13:-7])), 1)    #pmos

    #x_index = np.arange(-0.2, 0.15, 0.01)    #nmos
    x_index = np.arange(-0.1, 0.2, 0.01)    #pmos

    plt.plot(x_index, np.power(10, m*x_index) * np.power(10, b))

    print(1000/m)

plt.ylabel("Absolute Current Density (|A|/um)")
plt.xlabel("Gate Voltage Vg")
plt.title("Pmos Subthresh-Swing Extraction (Q3)")
plt.legend()
plt.show()
# Out:
# -73.41683458035492

# %%
with open("1.0um_Data/pmos_data/pmos_1.0_iv_low.txt", 'r') as file:
    lines = [line.rstrip() for line in file][6:]

    voltage = []
    current = []

    for line in lines:
        b, a = line.split("      ")
        voltage.append(float(b))
        current.append(float(a))

    plt.plot(voltage, np.abs(current))

    plt.yscale('log') 

    # Subthreshold Swing Extraction

    #m, b = np.polyfit(voltage[5:11], np.log10(np.abs(current[5:11])), 1)    #nmos
    m, b = np.polyfit(voltage[-13:-7], np.log10(np.abs(current[-13:-7])), 1)    #pmos

    #x_index = np.arange(-0.2, 0.15, 0.01)    #nmos
    x_index = np.arange(-0.1, 0.2, 0.01)    #pmos

    plt.plot(x_index, np.power(10, m*x_index) * np.power(10, b))

    print(1000/m)

plt.show()
# Out:
# -77.42827829399485

# %%
with open("0.5um_Data/pmos_data/pmos_0.5_iv_low.txt", 'r') as file:
    lines = [line.rstrip() for line in file][6:]

    voltage = []
    current = []

    for line in lines:
        b, a = line.split("      ")
        voltage.append(float(b))
        current.append(float(a))

    plt.plot(voltage, np.abs(current), label='0.5um Gate Length')

    plt.yscale('log') 

    # Subthreshold Swing Extraction

    #m, b = np.polyfit(voltage[5:10], np.log10(np.abs(current[5:10])), 1)    #nmos
    m, b = np.polyfit(voltage[-15:-8], np.log10(np.abs(current[-15:-8])), 1)    #pmos

    #x_index = np.arange(-0.2, 0.06, 0.01)    #nmos
    x_index = np.arange(-0.2, 0.1, 0.01)    #pmos

    plt.plot(x_index, np.power(10, m*x_index) * np.power(10, b))

    print(1000/m)

plt.show()
# Out:
# -448.37925912537025

# %%
with open("1.8um_Data/nmos_data/nmos_1a_low.txt", 'r') as file:
    lines = [line.rstrip() for line in file][6:]

    voltage = []
    current = []

    for line in lines:
        b, a = line.split("      ")
        voltage.append(float(b))
        current.append(float(a))

    plt.plot(voltage, np.abs(current))

    plt.yscale('log') 

    # Subthreshold Swing Extraction

    m, b = np.polyfit(voltage[8:15], np.log10(np.abs(current[8:15])), 1)    #nmos
    #m, b = np.polyfit(voltage[-15:-8], np.log10(np.abs(current[-15:-8])), 1)    #pmos

    x_index = np.arange(-0.1, 0.2, 0.01)    #nmos
    #x_index = np.arange(-0.2, 0.1, 0.01)    #pmos

    plt.plot(x_index, np.power(10, m*x_index) * np.power(10, b))

    plt.ylabel("Absolute Current Density (|A|/um)")
    plt.xlabel("Gate Voltage Vg")
    plt.title("Nmos Subthresh-Swing Extraction")

    plt.legend(['IV-curve', 'Subthreshold Swing: 73.77mV/Dec'])

    print(1000/m)

plt.show()
# Out:
# 73.7703821094628

# %%
thresholds = [73.77, 72.83, 76.92, 358.34]
bias = [1.8, 1.5, 1, 0.5]

plt.plot(bias, thresholds, 'ro-')
plt.xlabel("Gate Length (um)")
plt.ylabel("Subthreshold Swing (mV/Dec)")
plt.title("Nmos Gate Length Influence on Subthresh-Swing")
# Out:
# Text(0.5, 1.0, 'Nmos Gate Length Influence on Subthresh-Swing')
